# %%
from flask import Flask, request, render_template
import tensorflow as tf
import pickle
from keras.preprocessing.sequence import pad_sequences
from preprocessing import clean_text

app = Flask(__name__)

# Load model and tokenizer
model = tf.keras.models.load_model("sentiment_model.h5")
with open("tokenizer.pkl", "rb") as f:
    tokenizer = pickle.load(f)

max_len = 100

@app.route("/", methods=["GET", "POST"])
def index():
    result = ""
    if request.method == "POST":
        text = request.form["tweet"]
        cleaned = clean_text(text)
        seq = tokenizer.texts_to_sequences([cleaned])
        padded = pad_sequences(seq, maxlen=max_len)
        pred = float(model.predict(padded)[0][0])
        result = "Positive 😊" if pred >= 0.5 else "Negative 😞"
    return render_template("index.html", result=result)


if __name__ == "__main__":
    app.run(debug=True, use_reloader=False)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:40:04] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:40:05] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:41:10] "POST / HTTP/1.1" 200 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:42:45] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:42:51] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:42:52] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:43:06] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:44:13] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:44:13] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# INFO:werkzeug:127.0.0.1 - - [13/Sep/2025 15:44:24] "POST / HTTP/1.1" 200 -
